# %% [markdown]
# ### 1. Treinar com p=2%
#
# ### 2. Melhoria nos augmentation
#  - Crop nas imagens, como na predicao e validacao
#  - random crop
#
# ### 3. Otimizacao dos valores de LR inicial
#  - treinar a primeira epoca e verificar o melhor LR
#  - verificar para os tres casos, teacher finetune e pseudolabels
#
# ### 4. Otimizar o fator k_best na geracao de pseudolabels
#  - nao necessariamente 50%
#  - pode variar para as diferentes particoes
#
# ### 5. Repetir os experimentos
#  - com os valores encontrados, mais data augmentation, etc
#
# ### 6. Reduzir o tamanho inicial do conjunto para 10%
#  - 20% de 10%, 10% de 10%, 5% de 10%, 2% de 10%
#  - mesmos experimentos
#
# ### 7. Escrever um artigo
#
# ### 8. Realizar os experimentos para outra patologia (futuramente)
#  - sem necessariamente a reducao do conjunto

# %%
import os
import sys
#os.chdir('./ChexNet')
os.getcwd()
# Out:
# '/home/roberto/Documents/CheXNet'

# %%
import numpy as np
from torchvision.transforms import transforms

# %%
total = 50_000

train5 = 5_000   # rotulado
train95 = 45_000 # nao rotulado

total_validacao = 7371
total_teste = 22_000

# %%
from packaging import version
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

# %%
def tb_tags(path):
    ea = EventAccumulator(path)
    ea.Reload()
    return ea.Tags()['scalars']
    
def tb_values(path, tag):
    ea = EventAccumulator(path)
    ea.Reload()
    times, steps, vals = zip(*ea.Scalars(tag))
    return times, steps, vals

# %%
# 20%

teacher  = 'runs/effusion_train20%_teacher_00'
pseudo   = 'runs/effusion_train20%_pseudolabels_00'
finetune = 'runs/effusion_train20%_finetune_00'


#for folder in [teacher, pseudo, finetune]:
#    print(tb_tags(folder))


data_teacher = tb_values(teacher, 'auroc/validation')
data_pseudo = tb_values(pseudo, 'auroc/validation')
data_finetune = tb_values(finetune, 'auroc/validation')

# %%
plt.figure(figsize=(20,10)), plt.grid(which='major'), plt.ylim([0.6,1])


for data, c, l in zip([data_teacher, data_pseudo, data_finetune],
                      ['r', 'b', 'k'],
                      ['Teacher', 'Pseudo-labels only', 'Finetuned']):
    amax = np.argmax(data[2])
    plt.plot(data[2], '-'+c+'.', label=l + f'- Max : {round(data[2][amax], 3)}')    
    plt.plot(amax, data[2][amax], c+'x')
    
plt.legend(fontsize='large')
plt.title('Resultados treinamento - particao 20%')
plt.xlabel('Steps')
plt.ylabel('AUROC')
plt.savefig(fname='./images/auroc_20%_partition.png')

# %%
# 10%

teacher  = 'runs/effusion_train10%_teacher_00'
pseudo   = 'runs/effusion_train10%_pseudolabels_00'
finetune = 'runs/effusion_train10%_finetune_00'


#for folder in [teacher, pseudo, finetune]:
#    print(tb_tags(folder))


data_teacher = tb_values(teacher, 'auroc/validation')
data_pseudo = tb_values(pseudo, 'auroc/validation')
data_finetune = tb_values(finetune, 'auroc/validation')

# %%
plt.figure(figsize=(20,10)), plt.grid(which='major'), plt.ylim([0.6,1])


for data, c, l in zip([data_teacher, data_pseudo, data_finetune],
                      ['r', 'b', 'k'],
                      ['Teacher', 'Pseudo-labels only', 'Finetuned']):
    amax = np.argmax(data[2])
    plt.plot(data[2], '-'+c+'.', label=l + f'- Max : {round(data[2][amax], 2)}')    
    plt.plot(amax, data[2][amax], c+'x')
    
plt.legend(fontsize='large')
plt.title('Resultados treinamento - particao 10%')
plt.xlabel('Steps')
plt.ylabel('AUROC')
plt.savefig(fname='./images/auroc_10%_partition.png')

# %%
# 05%

teacher = './CheXNet/runs/effusion_train05%_teacher_00/'
pseudo = './CheXNet/runs/effusion_train05%_student_pseudolabels_01/'
finetune = './CheXNet/runs/effusion_train05%_student_finetune_00/'


for folder in [teacher, pseudo, finetune]:
    print(tb_tags(folder))


data_teacher = tb_values(teacher, 'auroc/train')
data_pseudo = tb_values(pseudo, 'auroc/train')
data_finetune = tb_values(finetune, 'auroc/train')
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/directory_watcher.py in Load(self)
#      89         try:
# ---> 90             for event in self._LoadInternal():
#      91                 yield event
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _LoadInternal(self)
#     111         if not self._loader:
# --> 112             self._InitializeLoader()
#     113
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _InitializeLoader(self)
#     174     def _InitializeLoader(self):
# --> 175         path = self._GetNextPath()
#     176         if path:
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/directory_watcher.py in _GetNextPath(self)
#     211             path
# --> 212             for path in io_wrapper.ListDirectoryAbsolute(self._directory)
#     213             if self._path_filter(path)
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/io_wrapper.py in ListDirectoryAbsolute(directory)
#      88     return (
# ---> 89         os.path.join(directory, path) for path in tf.io.gfile.listdir(directory)
#      90     )
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py in listdir(dirname)
#     653     """
# --> 654     return get_filesystem(dirname).listdir(dirname)
#     655
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/compat/tensorflow_stub/io/gfile.py in listdir(self, dirname)
#     186         if not self.isdir(dirname):
# --> 187             raise errors.NotFoundError(None, None, "Could not find directory")
#     188
#
# NotFoundError: Could not find directory
#
# During handling of the above exception, another exception occurred:
#
# DirectoryDeletedError                     Traceback (most recent call last)
# <ipython-input-10-fa9d9a9b7baa> in <module>
#       7
#       8 for folder in [teacher, pseudo, finetune]:
# ----> 9     print(tb_tags(folder))
#      10
#      11
#
# <ipython-input-5-8caa10410b40> in tb_tags(path)
#       1 def tb_tags(path):
#       2     ea = EventAccumulator(path)
# ----> 3     ea.Reload()
#       4     return ea.Tags()['scalars']
#       5
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/event_accumulator.py in Reload(self)
#     247         """
#     248         with self._generator_mutex:
# --> 249             for event in self._generator.Load():
#     250                 self._ProcessEvent(event)
#     251         return self
#
# ~/Documents/CheXNet/.env/lib/python3.8/site-packages/tensorboard/backend/event_processing/directory_watcher.py in Load(self)
#      92         except tf.errors.OpError:
#      93             if not tf.io.gfile.exists(self._directory):
# ---> 94                 raise DirectoryDeletedError(
#      95                     "Directory %s has been permanently deleted"
#      96                     % self._directory
#
# DirectoryDeletedError: Directory ./CheXNet/runs/effusion_train05%_teacher_00/ has been permanently deleted

# %%
plt.figure(figsize=(20,10)), plt.grid(which='major'), plt.ylim([0.6,1])


for data, c, l in zip([data_teacher, data_pseudo, data_finetune],
                      ['r', 'b', 'k'],
                      ['Teacher', 'Pseudo-labels only', 'Finetuned']):
    amax = np.argmax(data[2])
    plt.plot(data[2], '-'+c+'.', label=l + f'- Max : {round(data[2][amax], 2)}')    
    plt.plot(amax, data[2][amax], c+'x')
    
plt.legend(fontsize='large')
plt.title('Resultados treinamento - particao 05%')
plt.xlabel('Steps')
plt.ylabel('AUROC')
plt.savefig(fname='./images/auroc_05%_partition.png')

# %%
plt.plot([0.82, 0.84, 0.89])
plt.plot([0.87, 0.88, 0.89])
